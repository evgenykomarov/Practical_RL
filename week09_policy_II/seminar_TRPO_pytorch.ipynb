# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash

    # !pip install -q gymnasium

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Starting virtual X frame buffer: Xvfb.

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
from typing import Tuple

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import gymnasium as gym

env = gym.make("Acrobot-v1", render_mode="rgb_array")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# Action Space Discrete(3)

# %%
plt.imshow(env.render())

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $\pi_\theta \left( a \middle| s \right)$.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape: Tuple[int], n_actions: int):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple:
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        super().__init__()

        assert isinstance(state_shape, tuple)
        assert len(state_shape) == 1
        input_dim = state_shape[0]

        hidden_dim1 = 500
        # Prepare your model here.
        # <YOUR CODE>
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, n_actions),
            nn.ReLU(),
        )

    def forward(self, states: torch.Tensor):
        """
        takes agent's observation, returns log-probabilities
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for the given states.
        # <YOUR CODE>
        logit = self.model(states)
        log_probs = F.log_softmax(logit, dim=1)

        return log_probs

    def get_log_probs(self, states: torch.Tensor):
        '''
        Log-probs for training
        '''
        return self.forward(states)

    def get_probs(self, states: torch.Tensor):
        '''
        Probs for interaction
        '''
        return torch.exp(self.forward(states))

    def act(self, obs: np.ndarray, sample: bool = True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        with torch.no_grad():
            probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(torch.tensor(env.reset()[0][np.newaxis], dtype=torch.float32))
assert (
    isinstance(log_probs, torch.Tensor) and
    log_probs.requires_grad
), "log_probs must be a torch.Tensor with grad"
assert log_probs.shape == (1, n_actions)
sums = torch.exp(log_probs).sum(dim=1)
assert torch.allclose(sums, torch.ones_like(sums))

# Demo use
print("sampled:", [agent.act(env.reset()[0]) for _ in range(5)])
print("greedy:", [agent.act(env.reset()[0], sample=False) for _ in range(5)])
# Out:
# sampled: [(0, array([0.31319928, 0.35404673, 0.33275384], dtype=float32)), (1, array([0.31430316, 0.35608163, 0.3296152 ], dtype=float32)), (0, array([0.3130498, 0.3529064, 0.3340439], dtype=float32)), (1, array([0.3141678 , 0.35555887, 0.33027336], dtype=float32)), (1, array([0.31231916, 0.3571322 , 0.3305486 ], dtype=float32))]
# greedy: [(1, array([0.31415802, 0.3554272 , 0.33041474], dtype=float32)), (1, array([0.31375727, 0.354561  , 0.33168176], dtype=float32)), (1, array([0.3141457 , 0.3568499 , 0.32900432], dtype=float32)), (1, array([0.31174785, 0.35444745, 0.33380482], dtype=float32)), (1, array([0.31398275, 0.35350475, 0.33251244], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = [torch.ravel(param.detach()) for param in model.parameters()]
    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.shape)))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].reshape(param.shape)
        )
        prev_ind += flat_size

# %% [markdown]
# Compute cumulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cumulative_returns(r, gamma=1):
    """
    Computes cumulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cumulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation, _ = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, terminated, truncated, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if terminated or truncated or total_timesteps >= n_timesteps:
                path = {
                    "observations": np.array(obervations),
                    "policy": np.array(action_probs),
                    "actions": np.array(actions),
                    "rewards": np.array(rewards),
                    "cumulative_returns": get_cumulative_returns(rewards),
                }
                paths.append(path)
                break
    return paths

# %%
from pprint import pprint

paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
pprint(paths[-1])

assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,) + observation_shape)
assert (paths[0]['actions'].shape == (5,))

print("It's ok")
# Out:
# {'actions': array([0, 1, 2, 0, 2]),
#  'cumulative_returns': array([-5., -4., -3., -2., -1.]),
#  'observations': array([[ 0.999834  , -0.01821886,  0.99995565,  0.00941826,  0.03794222,
#         -0.09365306],
#        [ 0.9999895 ,  0.00458237,  0.99897206, -0.0453296 ,  0.18350962,
#         -0.44055015],
#        [ 0.9992859 ,  0.03778572,  0.99231315, -0.12375208,  0.13954853,
#         -0.3282471 ],
#        [ 0.99902844,  0.04407002,  0.99074006, -0.13577221, -0.07792939,
#          0.20934139],
#        [ 0.99939495,  0.03478123,  0.99368554, -0.11220077, -0.01249485,
#          0.02286011]], dtype=float32),
#  'policy': array([[0.31385025, 0.35575303, 0.33039674],
#        [0.31499463, 0.3580222 , 0.32698312],
#        [0.31515533, 0.35309815, 0.33174658],
#        [0.31358573, 0.35289276, 0.3335216 ],
#        [0.313579  , 0.35269132, 0.33372965]], dtype=float32),
#  'rewards': array([-1., -1., -1., -1., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be:
# $$J_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, in this assignment we are going to use cumulative rewards instead of advantage:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Since we want to maximize the reward, we are going to minimize the corresponding surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps]
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    probs_all = agent.get_probs(observations)

    probs_for_actions = probs_all[torch.arange(batch_size), actions]
    old_probs_for_actions = old_probs[torch.arange(batch_size), actions]

    # Compute surrogate loss, aka importance-sampled policy gradient
    # <YOUR CODE>
    importance_ratio = probs_for_actions / old_probs_for_actions
    loss = -torch.mean(importance_ratio * cumulative_returns, dim=0)

    assert loss.ndim == 0
    return loss

# %% [markdown]
# We can ascend these gradients as long as our $\pi_\theta(a|s)$ satisfies the constraint
# $$\mathbb{E}_{s,\pi_{\theta_{t}}} \Big[ \operatorname{KL} \left( \pi_{\theta_{t}} (s) \:\|\: \pi_{\theta_{t+1}} (s) \right) \Big] < \alpha$$
#
#
# where
#
# $$\operatorname{KL} \left( p \| q \right) = \mathbb{E}_p \log \left( \frac p q \right)$$

# %%
def get_kl(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps] (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above).
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took.
    # You will also need to compute max KL over all timesteps.
    old_log_probs = torch.log(old_probs + 1e-10)

    # <YOUR CODE>
    # kl = \int d\pi_{old} x ( log(\pi_{old}) - log(\pi_{new}) )
    kl = torch.max(torch.sum(old_probs * (old_log_probs - log_probs_all), dim=1))

    assert kl.ndim == 0
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = torch.tensor(observations, dtype=torch.float32)

    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = (-probs_all * log_probs_all).sum(dim=1).mean(dim=0)

    assert entropy.ndim == 0
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x: torch.Tensor, fullstep: torch.Tensor, max_kl: float, max_backtracks: int = 10, backtrack_coef: float = 0.5):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    loss, _, = f(x)
    for stepfrac in backtrack_coef**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        if kl <= max_kl and new_loss < loss:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve $A x = b$ using conjugate gradients.
#
# In general, CG is an algorithm that solves $A x = b$ where $A$ is positive-defined. $A$ is the Hessian matrix so $A$ is positive-defined. You can find out more about CG [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method).

# %%
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using an iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros_like(b)
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = A.T @ A


def f_Ax(x):
    return torch.ravel(torch.tensor(A, dtype=torch.float32) @ x.reshape(-1, 1))


b = np.random.rand(8)
w = (np.linalg.inv(A.T @ A) @ A.T @ b.reshape(-1, 1)).reshape(-1)

print(w)
print(conjugate_gradient(f_Ax, torch.tensor(b, dtype=torch.float32)).numpy())
# Out:
# [-204.97489787  169.3104351     5.80727869  -58.68452921   13.33375495
#  -269.58868495  206.77184075  129.04508307]
# [-204.86833   169.25829     5.77359   -58.612717   13.384256 -269.3897
#   206.54195   128.94319 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cumulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cumulative_returns - batch of cumulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = torch.tensor(observations, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int64)
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)
    old_probs = torch.tensor(old_probs, dtype=torch.float32)

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cumulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([torch.ravel(grad.detach()) for grad in grads])

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions, cumulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.reshape(-1) for grad in grads])

        kl_v = (flat_grad_kl * v).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([torch.ravel(grad) for grad in grads]).detach()

        return flat_grad_grad_kl + v * 0.1

    # Here we solve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [
            get_loss(agent, observations, actions, cumulative_returns, old_probs),
            get_kl(agent, observations, actions, cumulative_returns, old_probs),
        ]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count

# TRPO hyperparameter; controls how big KL divergence may be between the old and the new policy at every step.
max_kl = 0.01
numeptotal = 0  # Number of episodes we have completed so far.

start_time = time.time()

for i in count(1):
    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = {}
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
# Out:
# Streaming output truncated to the last 5000 lines.
# KL between old and new distribution:      0.009903353
# Entropy:                                  1.0349762
# Surrogate loss:                           250.4269
#
# ********** Iteration 80 ************
# Rollout
# Made rollout
# Total number of episodes:                 8018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             37.19 mins
# KL between old and new distribution:      0.0094902925
# Entropy:                                  1.0449132
# Surrogate loss:                           250.42564
#
# ********** Iteration 81 ************
# Rollout
# Made rollout
# Total number of episodes:                 8118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             37.72 mins
# KL between old and new distribution:      0.008485932
# Entropy:                                  1.0435019
# Surrogate loss:                           250.39558
#
# ********** Iteration 82 ************
# Rollout
# Made rollout
# Total number of episodes:                 8218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             38.13 mins
# KL between old and new distribution:      0.009588979
# Entropy:                                  1.0549253
# Surrogate loss:                           250.391
#
# ********** Iteration 83 ************
# Rollout
# Made rollout
# Total number of episodes:                 8318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             38.67 mins
# KL between old and new distribution:      0.008311331
# Entropy:                                  1.0480303
# Surrogate loss:                           250.46844
#
# ********** Iteration 84 ************
# Rollout
# Made rollout
# Total number of episodes:                 8418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             39.10 mins
# KL between old and new distribution:      0.009076167
# Entropy:                                  1.0565405
# Surrogate loss:                           250.41412
#
# ********** Iteration 85 ************
# Rollout
# Made rollout
# Total number of episodes:                 8518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             39.53 mins
# KL between old and new distribution:      0.009207301
# Entropy:                                  1.0586065
# Surrogate loss:                           250.4554
#
# ********** Iteration 86 ************
# Rollout
# Made rollout
# Total number of episodes:                 8618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             40.06 mins
# KL between old and new distribution:      0.009718068
# Entropy:                                  1.057217
# Surrogate loss:                           250.43117
#
# ********** Iteration 87 ************
# Rollout
# Made rollout
# Total number of episodes:                 8718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             40.53 mins
# KL between old and new distribution:      0.009930041
# Entropy:                                  1.0531713
# Surrogate loss:                           250.3752
#
# ********** Iteration 88 ************
# Rollout
# Made rollout
# Total number of episodes:                 8818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             40.97 mins
# KL between old and new distribution:      0.009492733
# Entropy:                                  1.0533932
# Surrogate loss:                           250.40044
#
# ********** Iteration 89 ************
# Rollout
# Made rollout
# Total number of episodes:                 8918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             41.43 mins
# KL between old and new distribution:      0.009966359
# Entropy:                                  1.0582596
# Surrogate loss:                           250.37267
#
# ********** Iteration 90 ************
# Rollout
# Made rollout
# Total number of episodes:                 9018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             41.96 mins
# KL between old and new distribution:      0.008777089
# Entropy:                                  1.0483979
# Surrogate loss:                           250.35757
#
# ********** Iteration 91 ************
# Rollout
# Made rollout
# Total number of episodes:                 9118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             42.37 mins
# KL between old and new distribution:      0.009311575
# Entropy:                                  1.0436943
# Surrogate loss:                           250.40938
#
# ********** Iteration 92 ************
# Rollout
# Made rollout
# Total number of episodes:                 9218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             42.91 mins
# KL between old and new distribution:      0.009760924
# Entropy:                                  1.0456634
# Surrogate loss:                           250.4308
#
# ********** Iteration 93 ************
# Rollout
# Made rollout
# Total number of episodes:                 9318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             43.37 mins
# KL between old and new distribution:      0.009772129
# Entropy:                                  1.0383962
# Surrogate loss:                           250.41441
#
# ********** Iteration 94 ************
# Rollout
# Made rollout
# Total number of episodes:                 9418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             43.81 mins
# KL between old and new distribution:      0.009213917
# Entropy:                                  1.0311317
# Surrogate loss:                           250.43704
#
# ********** Iteration 95 ************
# Rollout
# Made rollout
# Total number of episodes:                 9518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             44.23 mins
# KL between old and new distribution:      0.009443983
# Entropy:                                  1.0391688
# Surrogate loss:                           250.40408
#
# ********** Iteration 96 ************
# Rollout
# Made rollout
# Total number of episodes:                 9618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             44.70 mins
# KL between old and new distribution:      0.009180706
# Entropy:                                  1.0346116
# Surrogate loss:                           250.43942
#
# ********** Iteration 97 ************
# Rollout
# Made rollout
# Total number of episodes:                 9718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             45.22 mins
# KL between old and new distribution:      0.009798121
# Entropy:                                  1.0201336
# Surrogate loss:                           250.423
#
# ********** Iteration 98 ************
# Rollout
# Made rollout
# Total number of episodes:                 9818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             45.76 mins
# KL between old and new distribution:      0.009690333
# Entropy:                                  1.032402
# Surrogate loss:                           250.40771
#
# ********** Iteration 99 ************
# Rollout
# Made rollout
# Total number of episodes:                 9918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             46.19 mins
# KL between old and new distribution:      0.009689897
# Entropy:                                  1.0345376
# Surrogate loss:                           250.45213
#
# ********** Iteration 100 ************
# Rollout
# Made rollout
# Total number of episodes:                 10018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             46.72 mins
# KL between old and new distribution:      0.009889983
# Entropy:                                  1.0237062
# Surrogate loss:                           250.42065
#
# ********** Iteration 101 ************
# Rollout
# Made rollout
# Total number of episodes:                 10118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             47.22 mins
# KL between old and new distribution:      0.009987239
# Entropy:                                  1.0242062
# Surrogate loss:                           250.39224
#
# ********** Iteration 102 ************
# Rollout
# Made rollout
# Total number of episodes:                 10218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             47.65 mins
# KL between old and new distribution:      0.009363901
# Entropy:                                  1.0212283
# Surrogate loss:                           250.42027
#
# ********** Iteration 103 ************
# Rollout
# Made rollout
# Total number of episodes:                 10318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             48.10 mins
# KL between old and new distribution:      0.009938996
# Entropy:                                  1.0052752
# Surrogate loss:                           250.41852
#
# ********** Iteration 104 ************
# Rollout
# Made rollout
# Total number of episodes:                 10418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             48.56 mins
# KL between old and new distribution:      0.009152539
# Entropy:                                  1.0093274
# Surrogate loss:                           250.4522
#
# ********** Iteration 105 ************
# Rollout
# Made rollout
# Total number of episodes:                 10518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             48.99 mins
# KL between old and new distribution:      0.00997835
# Entropy:                                  1.0025662
# Surrogate loss:                           250.2763
#
# ********** Iteration 106 ************
# Rollout
# Made rollout
# Total number of episodes:                 10618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             49.42 mins
# KL between old and new distribution:      0.009200446
# Entropy:                                  1.0118393
# Surrogate loss:                           250.44974
#
# ********** Iteration 107 ************
# Rollout
# Made rollout
# Total number of episodes:                 10718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             49.84 mins
# KL between old and new distribution:      0.008771773
# Entropy:                                  1.0241127
# Surrogate loss:                           250.45415
#
# ********** Iteration 108 ************
# Rollout
# Made rollout
# Total number of episodes:                 10818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             50.28 mins
# KL between old and new distribution:      0.009274434
# Entropy:                                  1.0231732
# Surrogate loss:                           250.43706
#
# ********** Iteration 109 ************
# Rollout
# Made rollout
# Total number of episodes:                 10918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             50.73 mins
# KL between old and new distribution:      0.008665629
# Entropy:                                  1.0188284
# Surrogate loss:                           250.4232
#
# ********** Iteration 110 ************
# Rollout
# Made rollout
# Total number of episodes:                 11018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             51.19 mins
# KL between old and new distribution:      0.009604733
# Entropy:                                  1.0054165
# Surrogate loss:                           250.42198
#
# ********** Iteration 111 ************
# Rollout
# Made rollout
# Total number of episodes:                 11118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             51.72 mins
# KL between old and new distribution:      0.009722564
# Entropy:                                  1.0153267
# Surrogate loss:                           250.46956
#
# ********** Iteration 112 ************
# Rollout
# Made rollout
# Total number of episodes:                 11218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             52.14 mins
# KL between old and new distribution:      0.009749927
# Entropy:                                  1.0107762
# Surrogate loss:                           250.43448
#
# ********** Iteration 113 ************
# Rollout
# Made rollout
# Total number of episodes:                 11318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             52.54 mins
# KL between old and new distribution:      0.00951859
# Entropy:                                  1.0304964
# Surrogate loss:                           250.38667
#
# ********** Iteration 114 ************
# Rollout
# Made rollout
# Total number of episodes:                 11418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             52.96 mins
# KL between old and new distribution:      0.009430073
# Entropy:                                  1.0370094
# Surrogate loss:                           250.41562
#
# ********** Iteration 115 ************
# Rollout
# Made rollout
# Total number of episodes:                 11518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             53.37 mins
# KL between old and new distribution:      0.0099613555
# Entropy:                                  1.0116634
# Surrogate loss:                           250.38452
#
# ********** Iteration 116 ************
# Rollout
# Made rollout
# Total number of episodes:                 11618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             53.79 mins
# KL between old and new distribution:      0.008928329
# Entropy:                                  1.0156072
# Surrogate loss:                           250.46104
#
# ********** Iteration 117 ************
# Rollout
# Made rollout
# Total number of episodes:                 11718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             54.23 mins
# KL between old and new distribution:      0.009961687
# Entropy:                                  1.0273846
# Surrogate loss:                           250.4295
#
# ********** Iteration 118 ************
# Rollout
# Made rollout
# Total number of episodes:                 11818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             54.66 mins
# KL between old and new distribution:      0.009110443
# Entropy:                                  1.0323929
# Surrogate loss:                           250.4474
#
# ********** Iteration 119 ************
# Rollout
# Made rollout
# Total number of episodes:                 11918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             55.19 mins
# KL between old and new distribution:      0.009352036
# Entropy:                                  1.0308467
# Surrogate loss:                           250.42822
#
# ********** Iteration 120 ************
# Rollout
# Made rollout
# Total number of episodes:                 12018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             55.62 mins
# KL between old and new distribution:      0.009674501
# Entropy:                                  1.0250684
# Surrogate loss:                           250.34602
#
# ********** Iteration 121 ************
# Rollout
# Made rollout
# Total number of episodes:                 12118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             56.16 mins
# KL between old and new distribution:      0.009580672
# Entropy:                                  1.0279665
# Surrogate loss:                           250.43156
#
# ********** Iteration 122 ************
# Rollout
# Made rollout
# Total number of episodes:                 12218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             56.59 mins
# KL between old and new distribution:      0.009597659
# Entropy:                                  1.0234367
# Surrogate loss:                           250.46973
#
# ********** Iteration 123 ************
# Rollout
# Made rollout
# Total number of episodes:                 12318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             57.02 mins
# KL between old and new distribution:      0.009648163
# Entropy:                                  1.0360831
# Surrogate loss:                           250.41483
#
# ********** Iteration 124 ************
# Rollout
# Made rollout
# Total number of episodes:                 12418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             57.47 mins
# KL between old and new distribution:      0.009561069
# Entropy:                                  1.0294644
# Surrogate loss:                           250.45094
#
# ********** Iteration 125 ************
# Rollout
# Made rollout
# Total number of episodes:                 12518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             57.88 mins
# KL between old and new distribution:      0.009783536
# Entropy:                                  1.0362879
# Surrogate loss:                           250.4139
#
# ********** Iteration 126 ************
# Rollout
# Made rollout
# Total number of episodes:                 12618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             58.31 mins
# KL between old and new distribution:      0.009625532
# Entropy:                                  1.0226384
# Surrogate loss:                           250.45566
#
# ********** Iteration 127 ************
# Rollout
# Made rollout
# Total number of episodes:                 12718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             58.78 mins
# KL between old and new distribution:      0.009762198
# Entropy:                                  1.03389
# Surrogate loss:                           250.4189
#
# ********** Iteration 128 ************
# Rollout
# Made rollout
# Total number of episodes:                 12818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             59.19 mins
# KL between old and new distribution:      0.009583533
# Entropy:                                  1.0425518
# Surrogate loss:                           250.40955
#
# ********** Iteration 129 ************
# Rollout
# Made rollout
# Total number of episodes:                 12918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             59.62 mins
# KL between old and new distribution:      0.009612385
# Entropy:                                  1.0246319
# Surrogate loss:                           250.39255
#
# ********** Iteration 130 ************
# Rollout
# Made rollout
# Total number of episodes:                 13018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             60.04 mins
# KL between old and new distribution:      0.009780347
# Entropy:                                  1.0317645
# Surrogate loss:                           250.37495
#
# ********** Iteration 131 ************
# Rollout
# Made rollout
# Total number of episodes:                 13118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             60.58 mins
# KL between old and new distribution:      0.009643175
# Entropy:                                  1.037112
# Surrogate loss:                           250.42557
#
# ********** Iteration 132 ************
# Rollout
# Made rollout
# Total number of episodes:                 13218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             61.00 mins
# KL between old and new distribution:      0.009744272
# Entropy:                                  1.0227548
# Surrogate loss:                           250.40659
#
# ********** Iteration 133 ************
# Rollout
# Made rollout
# Total number of episodes:                 13318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             61.53 mins
# KL between old and new distribution:      0.008656967
# Entropy:                                  1.0158414
# Surrogate loss:                           250.46117
#
# ********** Iteration 134 ************
# Rollout
# Made rollout
# Total number of episodes:                 13418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             62.00 mins
# KL between old and new distribution:      0.00987912
# Entropy:                                  1.0120124
# Surrogate loss:                           250.41322
#
# ********** Iteration 135 ************
# Rollout
# Made rollout
# Total number of episodes:                 13518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             62.41 mins
# KL between old and new distribution:      0.009181928
# Entropy:                                  1.0211742
# Surrogate loss:                           250.45879
#
# ********** Iteration 136 ************
# Rollout
# Made rollout
# Total number of episodes:                 13618
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             62.85 mins
# KL between old and new distribution:      0.009673305
# Entropy:                                  1.0276687
# Surrogate loss:                           250.43053
#
# ********** Iteration 137 ************
# Rollout
# Made rollout
# Total number of episodes:                 13718
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             63.28 mins
# KL between old and new distribution:      0.009563344
# Entropy:                                  1.0222846
# Surrogate loss:                           250.43153
#
# ********** Iteration 138 ************
# Rollout
# Made rollout
# Total number of episodes:                 13818
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             63.80 mins
# KL between old and new distribution:      0.00960996
# Entropy:                                  1.0286242
# Surrogate loss:                           250.37886
#
# ********** Iteration 139 ************
# Rollout
# Made rollout
# Total number of episodes:                 13918
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             64.24 mins
# KL between old and new distribution:      0.009481598
# Entropy:                                  1.0183725
# Surrogate loss:                           250.45753
#
# ********** Iteration 140 ************
# Rollout
# Made rollout
# Total number of episodes:                 14018
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             64.73 mins
# KL between old and new distribution:      0.009448051
# Entropy:                                  1.0286045
# Surrogate loss:                           250.46068
#
# ********** Iteration 141 ************
# Rollout
# Made rollout
# Total number of episodes:                 14118
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             65.16 mins
# KL between old and new distribution:      0.009201277
# Entropy:                                  1.0211421
# Surrogate loss:                           250.42116
#
# ********** Iteration 142 ************
# Rollout
# Made rollout
# Total number of episodes:                 14218
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             65.62 mins
# KL between old and new distribution:      0.009689435
# Entropy:                                  1.024779
# Surrogate loss:                           250.45926
#
# ********** Iteration 143 ************
# Rollout
# Made rollout
# Total number of episodes:                 14318
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             66.15 mins
# KL between old and new distribution:      0.009474479
# Entropy:                                  1.0240626
# Surrogate loss:                           250.4255
#
# ********** Iteration 144 ************
# Rollout
# Made rollout
# Total number of episodes:                 14418
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             66.59 mins
# KL between old and new distribution:      0.009982683
# Entropy:                                  1.0356064
# Surrogate loss:                           250.4471
#
# ********** Iteration 145 ************
# Rollout
# Made rollout
# Total number of episodes:                 14518
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             67.02 mins
# KL between old and new distribution:      0.009249911
# Entropy:                                  1.0366299
# Surrogate loss:                           250.44836
#
# ********** Iteration 146 ************
# Rollout
# Made rollout
# Total number of episodes:                 14619
# Average sum of rewards per episode:       -495.03960396039605
# Std of rewards per episode:               39.3058383268418
# Time elapsed:                             67.51 mins
# KL between old and new distribution:      0.009764209
# Entropy:                                  1.0339608
# Surrogate loss:                           249.5
#
# ********** Iteration 147 ************
# Rollout
# Made rollout
# Total number of episodes:                 14720
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               44.22253702694919
# Time elapsed:                             68.05 mins
# KL between old and new distribution:      0.009148389
# Entropy:                                  1.0276176
# Surrogate loss:                           249.87914
#
# ********** Iteration 148 ************
# Rollout
# Made rollout
# Total number of episodes:                 14820
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             68.47 mins
# KL between old and new distribution:      0.009617966
# Entropy:                                  1.0362189
# Surrogate loss:                           250.40198
#
# ********** Iteration 149 ************
# Rollout
# Made rollout
# Total number of episodes:                 14921
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               33.956132284371755
# Time elapsed:                             68.95 mins
# KL between old and new distribution:      0.009799097
# Entropy:                                  1.0262645
# Surrogate loss:                           249.03365
#
# ********** Iteration 150 ************
# Rollout
# Made rollout
# Total number of episodes:                 15022
# Average sum of rewards per episode:       -495.03960396039605
# Std of rewards per episode:               48.90887076438295
# Time elapsed:                             69.38 mins
# KL between old and new distribution:      0.009079199
# Entropy:                                  1.0295937
# Surrogate loss:                           250.35248
#
# ********** Iteration 151 ************
# Rollout
# Made rollout
# Total number of episodes:                 15123
# Average sum of rewards per episode:       -495.019801980198
# Std of rewards per episode:               35.48698832748206
# Time elapsed:                             69.92 mins
# KL between old and new distribution:      0.009242561
# Entropy:                                  1.0290987
# Surrogate loss:                           249.22392
#
# ********** Iteration 152 ************
# Rollout
# Made rollout
# Total number of episodes:                 15224
# Average sum of rewards per episode:       -494.970297029703
# Std of rewards per episode:               23.555897474992697
# Time elapsed:                             70.44 mins
# KL between old and new distribution:      0.008572407
# Entropy:                                  1.0267875
# Surrogate loss:                           248.43236
#
# ********** Iteration 153 ************
# Rollout
# Made rollout
# Total number of episodes:                 15325
# Average sum of rewards per episode:       -494.94059405940595
# Std of rewards per episode:               17.62020767354842
# Time elapsed:                             70.87 mins
# KL between old and new distribution:      0.009093724
# Entropy:                                  1.030827
# Surrogate loss:                           248.20088
#
# ********** Iteration 154 ************
# Rollout
# Made rollout
# Total number of episodes:                 15428
# Average sum of rewards per episode:       -485.29126213592235
# Std of rewards per episode:               55.82403544494494
# Time elapsed:                             71.29 mins
# KL between old and new distribution:      0.009230319
# Entropy:                                  1.02355
# Surrogate loss:                           246.11012
#
# ********** Iteration 155 ************
# Rollout
# Made rollout
# Total number of episodes:                 15532
# Average sum of rewards per episode:       -480.53846153846155
# Std of rewards per episode:               61.288868840817926
# Time elapsed:                             71.73 mins
# KL between old and new distribution:      0.009745218
# Entropy:                                  1.0137212
# Surrogate loss:                           244.46062
#
# ********** Iteration 156 ************
# Rollout
# Made rollout
# Total number of episodes:                 15634
# Average sum of rewards per episode:       -490.078431372549
# Std of rewards per episode:               32.90112527860151
# Time elapsed:                             72.27 mins
# KL between old and new distribution:      0.009330753
# Entropy:                                  1.0066899
# Surrogate loss:                           246.51584
#
# ********** Iteration 157 ************
# Rollout
# Made rollout
# Total number of episodes:                 15736
# Average sum of rewards per episode:       -490.11764705882354
# Std of rewards per episode:               54.55637381530624
# Time elapsed:                             72.73 mins
# KL between old and new distribution:      0.00877073
# Entropy:                                  1.0188998
# Surrogate loss:                           248.51172
#
# ********** Iteration 158 ************
# Rollout
# Made rollout
# Total number of episodes:                 15837
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               32.93661943660541
# Time elapsed:                             73.15 mins
# KL between old and new distribution:      0.008921638
# Entropy:                                  1.0242649
# Surrogate loss:                           249.00607
#
# ********** Iteration 159 ************
# Rollout
# Made rollout
# Total number of episodes:                 15940
# Average sum of rewards per episode:       -485.3009708737864
# Std of rewards per episode:               52.115226135688104
# Time elapsed:                             73.65 mins
# KL between old and new distribution:      0.00956662
# Entropy:                                  1.0277243
# Surrogate loss:                           245.8338
#
# ********** Iteration 160 ************
# Rollout
# Made rollout
# Total number of episodes:                 16042
# Average sum of rewards per episode:       -490.12745098039215
# Std of rewards per episode:               47.95497716274057
# Time elapsed:                             74.14 mins
# KL between old and new distribution:      0.009741381
# Entropy:                                  1.0320044
# Surrogate loss:                           247.74976
#
# ********** Iteration 161 ************
# Rollout
# Made rollout
# Total number of episodes:                 16144
# Average sum of rewards per episode:       -490.05882352941177
# Std of rewards per episode:               29.12913221697406
# Time elapsed:                             74.67 mins
# KL between old and new distribution:      0.009408876
# Entropy:                                  1.0354246
# Surrogate loss:                           246.2663
#
# ********** Iteration 162 ************
# Rollout
# Made rollout
# Total number of episodes:                 16246
# Average sum of rewards per episode:       -490.0882352941176
# Std of rewards per episode:               34.974249053922705
# Time elapsed:                             75.20 mins
# KL between old and new distribution:      0.0096782
# Entropy:                                  1.0377395
# Surrogate loss:                           246.66335
#
# ********** Iteration 163 ************
# Rollout
# Made rollout
# Total number of episodes:                 16349
# Average sum of rewards per episode:       -485.2621359223301
# Std of rewards per episode:               35.47375925156278
# Time elapsed:                             75.72 mins
# KL between old and new distribution:      0.009044647
# Entropy:                                  1.0316459
# Surrogate loss:                           244.28456
#
# ********** Iteration 164 ************
# Rollout
# Made rollout
# Total number of episodes:                 16453
# Average sum of rewards per episode:       -480.50961538461536
# Std of rewards per episode:               49.39810709397128
# Time elapsed:                             76.25 mins
# KL between old and new distribution:      0.009214457
# Entropy:                                  1.0255164
# Surrogate loss:                           243.11565
#
# ********** Iteration 165 ************
# Rollout
# Made rollout
# Total number of episodes:                 16557
# Average sum of rewards per episode:       -480.625
# Std of rewards per episode:               53.808096956470436
# Time elapsed:                             76.68 mins
# KL between old and new distribution:      0.009992488
# Entropy:                                  1.0299646
# Surrogate loss:                           243.69917
#
# ********** Iteration 166 ************
# Rollout
# Made rollout
# Total number of episodes:                 16661
# Average sum of rewards per episode:       -480.4807692307692
# Std of rewards per episode:               39.74001586495337
# Time elapsed:                             77.08 mins
# KL between old and new distribution:      0.009633038
# Entropy:                                  1.0319393
# Surrogate loss:                           242.17628
#
# ********** Iteration 167 ************
# Rollout
# Made rollout
# Total number of episodes:                 16765
# Average sum of rewards per episode:       -480.5
# Std of rewards per episode:               46.63875080791806
# Time elapsed:                             77.52 mins
# KL between old and new distribution:      0.009132475
# Entropy:                                  1.0315633
# Surrogate loss:                           242.82384
#
# ********** Iteration 168 ************
# Rollout
# Made rollout
# Total number of episodes:                 16875
# Average sum of rewards per episode:       -454.08181818181816
# Std of rewards per episode:               73.43013151885289
# Time elapsed:                             78.06 mins
# KL between old and new distribution:      0.009023298
# Entropy:                                  1.0253042
# Surrogate loss:                           233.1532
#
# ********** Iteration 169 ************
# Rollout
# Made rollout
# Total number of episodes:                 16986
# Average sum of rewards per episode:       -449.963963963964
# Std of rewards per episode:               67.17932542432358
# Time elapsed:                             78.59 mins
# KL between old and new distribution:      0.00934048
# Entropy:                                  1.0236111
# Surrogate loss:                           230.06029
#
# ********** Iteration 170 ************
# Rollout
# Made rollout
# Total number of episodes:                 17099
# Average sum of rewards per episode:       -441.9380530973451
# Std of rewards per episode:               72.76246761589867
# Time elapsed:                             79.12 mins
# KL between old and new distribution:      0.009064794
# Entropy:                                  1.0210786
# Surrogate loss:                           227.12692
#
# ********** Iteration 171 ************
# Rollout
# Made rollout
# Total number of episodes:                 17215
# Average sum of rewards per episode:       -430.42241379310343
# Std of rewards per episode:               74.52922949652718
# Time elapsed:                             79.53 mins
# KL between old and new distribution:      0.008122757
# Entropy:                                  1.0232804
# Surrogate loss:                           221.79926
#
# ********** Iteration 172 ************
# Rollout
# Made rollout
# Total number of episodes:                 17333
# Average sum of rewards per episode:       -423.0762711864407
# Std of rewards per episode:               78.69261770338564
# Time elapsed:                             79.98 mins
# KL between old and new distribution:      0.009752858
# Entropy:                                  1.0165373
# Surrogate loss:                           218.93518
#
# ********** Iteration 173 ************
# Rollout
# Made rollout
# Total number of episodes:                 17453
# Average sum of rewards per episode:       -415.975
# Std of rewards per episode:               79.2604843222649
# Time elapsed:                             80.51 mins
# KL between old and new distribution:      0.008666962
# Entropy:                                  1.0156872
# Surrogate loss:                           215.6289
#
# ********** Iteration 174 ************
# Rollout
# Made rollout
# Total number of episodes:                 17580
# Average sum of rewards per episode:       -392.88188976377955
# Std of rewards per episode:               86.18736357798214
# Time elapsed:                             80.99 mins
# KL between old and new distribution:      0.009571169
# Entropy:                                  1.0086076
# Surrogate loss:                           205.92316
#
# ********** Iteration 175 ************
# Rollout
# Made rollout
# Total number of episodes:                 17712
# Average sum of rewards per episode:       -377.99242424242425
# Std of rewards per episode:               92.75517597353057
# Time elapsed:                             81.42 mins
# KL between old and new distribution:      0.009075396
# Entropy:                                  1.0124282
# Surrogate loss:                           200.35011
#
# ********** Iteration 176 ************
# Rollout
# Made rollout
# Total number of episodes:                 17851
# Average sum of rewards per episode:       -358.7913669064748
# Std of rewards per episode:               85.69264760483976
# Time elapsed:                             81.90 mins
# KL between old and new distribution:      0.009062696
# Entropy:                                  1.005492
# Surrogate loss:                           189.5872
#
# ********** Iteration 177 ************
# Rollout
# Made rollout
# Total number of episodes:                 17995
# Average sum of rewards per episode:       -346.27777777777777
# Std of rewards per episode:               76.1467374040671
# Time elapsed:                             82.32 mins
# KL between old and new distribution:      0.008777544
# Entropy:                                  1.0018973
# Surrogate loss:                           181.4946
#
# ********** Iteration 178 ************
# Rollout
# Made rollout
# Total number of episodes:                 18145
# Average sum of rewards per episode:       -332.4066666666667
# Std of rewards per episode:               76.20202067895283
# Time elapsed:                             82.86 mins
# KL between old and new distribution:      0.007210713
# Entropy:                                  0.996527
# Surrogate loss:                           174.87674
#
# ********** Iteration 179 ************
# Rollout
# Made rollout
# Total number of episodes:                 18300
# Average sum of rewards per episode:       -321.6516129032258
# Std of rewards per episode:               84.45954126267658
# Time elapsed:                             83.26 mins
# KL between old and new distribution:      0.007892378
# Entropy:                                  0.99012554
# Surrogate loss:                           171.86807
#
# ********** Iteration 180 ************
# Rollout
# Made rollout
# Total number of episodes:                 18465
# Average sum of rewards per episode:       -302.03636363636366
# Std of rewards per episode:               66.62303641171162
# Time elapsed:                             83.69 mins
# KL between old and new distribution:      0.0095607415
# Entropy:                                  0.99683374
# Surrogate loss:                           158.22412
#
# ********** Iteration 181 ************
# Rollout
# Made rollout
# Total number of episodes:                 18619
# Average sum of rewards per episode:       -323.7402597402597
# Std of rewards per episode:               78.42473480034194
# Time elapsed:                             84.09 mins
# KL between old and new distribution:      0.009486094
# Entropy:                                  0.98361164
# Surrogate loss:                           171.32478
#
# ********** Iteration 182 ************
# Rollout
# Made rollout
# Total number of episodes:                 18788
# Average sum of rewards per episode:       -294.88757396449705
# Std of rewards per episode:               75.36125477546992
# Time elapsed:                             84.52 mins
# KL between old and new distribution:      0.008912113
# Entropy:                                  0.9713873
# Surrogate loss:                           157.01942
#
# ********** Iteration 183 ************
# Rollout
# Made rollout
# Total number of episodes:                 18954
# Average sum of rewards per episode:       -300.2530120481928
# Std of rewards per episode:               79.03786546760074
# Time elapsed:                             84.98 mins
# KL between old and new distribution:      0.008948464
# Entropy:                                  0.95908296
# Surrogate loss:                           160.44592
#
# ********** Iteration 184 ************
# Rollout
# Made rollout
# Total number of episodes:                 19136
# Average sum of rewards per episode:       -273.74175824175825
# Std of rewards per episode:               64.17758940256303
# Time elapsed:                             85.51 mins
# KL between old and new distribution:      0.009927757
# Entropy:                                  0.9591377
# Surrogate loss:                           144.31262
#
# ********** Iteration 185 ************
# Rollout
# Made rollout
# Total number of episodes:                 19326
# Average sum of rewards per episode:       -262.1736842105263
# Std of rewards per episode:               67.03617516806456
# Time elapsed:                             86.03 mins
# KL between old and new distribution:      0.009100016
# Entropy:                                  0.94483256
# Surrogate loss:                           139.54959
#
# ********** Iteration 186 ************
# Rollout
# Made rollout
# Total number of episodes:                 19523
# Average sum of rewards per episode:       -252.82741116751268
# Std of rewards per episode:               68.81676294945217
# Time elapsed:                             86.54 mins
# KL between old and new distribution:      0.008567907
# Entropy:                                  0.9306011
# Surrogate loss:                           135.7018
#
# ********** Iteration 187 ************
# Rollout
# Made rollout
# Total number of episodes:                 19729
# Average sum of rewards per episode:       -241.72815533980582
# Std of rewards per episode:               56.05600427290399
# Time elapsed:                             86.99 mins
# KL between old and new distribution:      0.009626411
# Entropy:                                  0.9184268
# Surrogate loss:                           127.3028
#
# ********** Iteration 188 ************
# Rollout
# Made rollout
# Total number of episodes:                 19938
# Average sum of rewards per episode:       -238.244019138756
# Std of rewards per episode:               63.6448938413459
# Time elapsed:                             87.42 mins
# KL between old and new distribution:      0.008706059
# Entropy:                                  0.8928008
# Surrogate loss:                           127.51891
#
# ********** Iteration 189 ************
# Rollout
# Made rollout
# Total number of episodes:                 20153
# Average sum of rewards per episode:       -231.56744186046512
# Std of rewards per episode:               62.14532002035765
# Time elapsed:                             87.84 mins
# KL between old and new distribution:      0.009100534
# Entropy:                                  0.870124
# Surrogate loss:                           124.01013
#
# ********** Iteration 190 ************
# Rollout
# Made rollout
# Total number of episodes:                 20377
# Average sum of rewards per episode:       -222.22321428571428
# Std of rewards per episode:               58.81124616417045
# Time elapsed:                             88.26 mins
# KL between old and new distribution:      0.009590458
# Entropy:                                  0.8567691
# Surrogate loss:                           118.80776
#
# ********** Iteration 191 ************
# Rollout
# Made rollout
# Total number of episodes:                 20613
# Average sum of rewards per episode:       -210.8728813559322
# Std of rewards per episode:               55.82957520856642
# Time elapsed:                             88.67 mins
# KL between old and new distribution:      0.009635389
# Entropy:                                  0.8448294
# Surrogate loss:                           112.7322
#
# ********** Iteration 192 ************
# Rollout
# Made rollout
# Total number of episodes:                 20860
# Average sum of rewards per episode:       -201.4331983805668
# Std of rewards per episode:               45.860581177790294
# Time elapsed:                             89.20 mins
# KL between old and new distribution:      0.009712264
# ...
#
# ********** Iteration 498 ************
# Rollout
# Made rollout
# Total number of episodes:                 132990
# Average sum of rewards per episode:       -91.0865561694291
# Std of rewards per episode:               34.42468309762743
# Time elapsed:                             222.77 mins
# KL between old and new distribution:      0.009148266
# Entropy:                                  0.29320228
# Surrogate loss:                           51.97128
#
# ********** Iteration 499 ************
# Rollout
# Made rollout
# Total number of episodes:                 133542
# Average sum of rewards per episode:       -89.58152173913044
# Std of rewards per episode:               25.380593248116543
# Time elapsed:                             223.18 mins
# KL between old and new distribution:      0.009792212
# Entropy:                                  0.29338855
# Surrogate loss:                           48.31867
#
# ********** Iteration 500 ************
# Rollout
# Made rollout
# Total number of episodes:                 134103
# Average sum of rewards per episode:       -88.1283422459893
# Std of rewards per episode:               21.673100348439473
# Time elapsed:                             223.58 mins
# KL between old and new distribution:      0.009557515
# Entropy:                                  0.2978998
# Surrogate loss:                           46.68352
#
# ********** Iteration 501 ************
# Rollout
# Made rollout
# Total number of episodes:                 134642
# Average sum of rewards per episode:       -91.76808905380334
# Std of rewards per episode:               32.95023546110068
# Time elapsed:                             223.98 mins
# KL between old and new distribution:      0.009890851
# Entropy:                                  0.2870275
# Surrogate loss:                           51.70459
#
# ********** Iteration 502 ************
# Rollout
# Made rollout
# Total number of episodes:                 135178
# Average sum of rewards per episode:       -92.28917910447761
# Std of rewards per episode:               37.40775164198217
# Time elapsed:                             224.39 mins
# KL between old and new distribution:      0.009297747
# Entropy:                                  0.28286308
# Surrogate loss:                           53.640034
#
# ********** Iteration 503 ************
# Rollout
# Made rollout
# Total number of episodes:                 135727
# Average sum of rewards per episode:       -90.0783242258652
# Std of rewards per episode:               31.871086875294136
# Time elapsed:                             224.79 mins
# KL between old and new distribution:      0.009365495
# Entropy:                                  0.28894404
# Surrogate loss:                           50.60654
#
# ********** Iteration 504 ************
# Rollout
# Made rollout
# Total number of episodes:                 136275
# Average sum of rewards per episode:       -90.2463503649635
# Std of rewards per episode:               35.506957853683126
# Time elapsed:                             225.19 mins
# KL between old and new distribution:      0.009670176
# Entropy:                                  0.28927875
# Surrogate loss:                           52.02202
#
# ********** Iteration 505 ************
# Rollout
# Made rollout
# Total number of episodes:                 136839
# Average sum of rewards per episode:       -87.65425531914893
# Std of rewards per episode:               23.049191143914634
# Time elapsed:                             225.59 mins
# KL between old and new distribution:      0.009232625
# Entropy:                                  0.2932609
# Surrogate loss:                           46.81406
#
# ********** Iteration 506 ************
# Rollout
# Made rollout
# Total number of episodes:                 137386
# Average sum of rewards per episode:       -90.41316270566728
# Std of rewards per episode:               36.52508154365438
# Time elapsed:                             225.99 mins
# KL between old and new distribution:      0.008948557
# Entropy:                                  0.2798021
# Surrogate loss:                           52.49988
#
# ********** Iteration 507 ************
# Rollout
# Made rollout
# Total number of episodes:                 137930
# Average sum of rewards per episode:       -90.91360294117646
# Std of rewards per episode:               29.28940719412943
# Time elapsed:                             226.39 mins
# KL between old and new distribution:      0.008825883
# Entropy:                                  0.2827475
# Surrogate loss:                           50.116177
#
# ********** Iteration 508 ************
# Rollout
# Made rollout
# Total number of episodes:                 138490
# Average sum of rewards per episode:       -88.2875
# Std of rewards per episode:               21.040212879999917
# Time elapsed:                             226.78 mins
# KL between old and new distribution:      0.009527747
# Entropy:                                  0.28883675
# Surrogate loss:                           46.60533
#
# ********** Iteration 509 ************
# Rollout
# Made rollout
# Total number of episodes:                 139035
# Average sum of rewards per episode:       -90.74495412844037
# Std of rewards per episode:               26.93306513330705
# Time elapsed:                             227.23 mins
# KL between old and new distribution:      0.008636769
# Entropy:                                  0.27561942
# Surrogate loss:                           49.318134
#
# ********** Iteration 510 ************
# Rollout
# Made rollout
# Total number of episodes:                 139599
# Average sum of rewards per episode:       -87.65425531914893
# Std of rewards per episode:               23.554207127000065
# Time elapsed:                             227.63 mins
# KL between old and new distribution:      0.009053677
# Entropy:                                  0.28383237
# Surrogate loss:                           46.94479
#
# ********** Iteration 511 ************
# Rollout
# Made rollout
# Total number of episodes:                 140150
# Average sum of rewards per episode:       -89.7459165154265
# Std of rewards per episode:               27.84871068096226
# Time elapsed:                             228.03 mins
# KL between old and new distribution:      0.008989099
# Entropy:                                  0.27835637
# Surrogate loss:                           49.13725
#
# ********** Iteration 512 ************
# Rollout
# Made rollout
# Total number of episodes:                 140710
# Average sum of rewards per episode:       -88.2875
# Std of rewards per episode:               23.39065413563411
# Time elapsed:                             228.44 mins
# KL between old and new distribution:      0.0096831955
# Entropy:                                  0.27647778
# Surrogate loss:                           47.195744
#
# ********** Iteration 513 ************
# Rollout
# Made rollout
# Total number of episodes:                 141261
# Average sum of rewards per episode:       -89.74773139745916
# Std of rewards per episode:               32.97587345136844
# Time elapsed:                             228.84 mins
# KL between old and new distribution:      0.009373423
# Entropy:                                  0.27513778
# Surrogate loss:                           50.85986
#
# ********** Iteration 514 ************
# Rollout
# Made rollout
# Total number of episodes:                 141824
# Average sum of rewards per episode:       -87.81172291296625
# Std of rewards per episode:               23.863140070987235
# Time elapsed:                             229.25 mins
# KL between old and new distribution:      0.009664487
# Entropy:                                  0.28293696
# Surrogate loss:                           47.097397
#
# ********** Iteration 515 ************
# Rollout
# Made rollout
# Total number of episodes:                 142366
# Average sum of rewards per episode:       -91.25461254612546
# Std of rewards per episode:               35.875267294442075
# Time elapsed:                             229.65 mins
# KL between old and new distribution:      0.009917643
# Entropy:                                  0.27118677
# Surrogate loss:                           52.58903
#
# ********** Iteration 516 ************
# Rollout
# Made rollout
# Total number of episodes:                 142915
# Average sum of rewards per episode:       -90.08014571948998
# Std of rewards per episode:               34.27289161177268
# Time elapsed:                             230.06 mins
# KL between old and new distribution:      0.008824874
# Entropy:                                  0.2731199
# Surrogate loss:                           51.481216
#
# ********** Iteration 517 ************
# Rollout
# Made rollout
# Total number of episodes:                 143456
# Average sum of rewards per episode:       -91.42329020332717
# Std of rewards per episode:               31.746921679505473
# Time elapsed:                             230.46 mins
# KL between old and new distribution:      0.009436626
# Entropy:                                  0.26887095
# Surrogate loss:                           51.15591
#
# ********** Iteration 518 ************
# Rollout
# Made rollout
# Total number of episodes:                 144006
# Average sum of rewards per episode:       -89.91636363636364
# Std of rewards per episode:               39.637543101717284
# Time elapsed:                             230.87 mins
# KL between old and new distribution:      0.008845858
# Entropy:                                  0.2676709
# Surrogate loss:                           53.5917
#
# ********** Iteration 519 ************
# Rollout
# Made rollout
# Total number of episodes:                 144572
# Average sum of rewards per episode:       -87.34098939929329
# Std of rewards per episode:               24.602392549555663
# Time elapsed:                             231.27 mins
# KL between old and new distribution:      0.009386439
# Entropy:                                  0.2778538
# Surrogate loss:                           47.090435
#
# ********** Iteration 520 ************
# Rollout
# Made rollout
# Total number of episodes:                 145138
# Average sum of rewards per episode:       -87.34098939929329
# Std of rewards per episode:               22.868466610134305
# Time elapsed:                             231.67 mins
# KL between old and new distribution:      0.009936702
# Entropy:                                  0.2737737
# Surrogate loss:                           46.62478
#
# ********** Iteration 521 ************
# Rollout
# Made rollout
# Total number of episodes:                 145699
# Average sum of rewards per episode:       -88.1301247771836
# Std of rewards per episode:               28.082813011082894
# Time elapsed:                             232.07 mins
# KL between old and new distribution:      0.009539854
# Entropy:                                  0.2641053
# Surrogate loss:                           48.472645
#
# ********** Iteration 522 ************
# Rollout
# Made rollout
# Total number of episodes:                 146244
# Average sum of rewards per episode:       -90.74678899082569
# Std of rewards per episode:               34.389380078252124
# Time elapsed:                             232.48 mins
# KL between old and new distribution:      0.008206114
# Entropy:                                  0.25658587
# Surrogate loss:                           51.813286
#
# ********** Iteration 523 ************
# Rollout
# Made rollout
# Total number of episodes:                 146791
# Average sum of rewards per episode:       -90.41316270566728
# Std of rewards per episode:               36.76041869323394
# Time elapsed:                             232.88 mins
# KL between old and new distribution:      0.009747863
# Entropy:                                  0.2611701
# Surrogate loss:                           52.57665
#
# ********** Iteration 524 ************
# Rollout
# Made rollout
# Total number of episodes:                 147349
# Average sum of rewards per episode:       -88.60752688172043
# Std of rewards per episode:               30.072583889133814
# Time elapsed:                             233.28 mins
# KL between old and new distribution:      0.0085820705
# Entropy:                                  0.26232132
# Surrogate loss:                           49.34448
#
# ********** Iteration 525 ************
# Rollout
# Made rollout
# Total number of episodes:                 147913
# Average sum of rewards per episode:       -87.65425531914893
# Std of rewards per episode:               24.276538442943043
# Time elapsed:                             233.68 mins
# KL between old and new distribution:      0.0097309835
# Entropy:                                  0.2613749
# Surrogate loss:                           47.141464
#
# ********** Iteration 526 ************
# Rollout
# Made rollout
# Total number of episodes:                 148466
# Average sum of rewards per episode:       -89.41952983725136
# Std of rewards per episode:               31.18035585846773
# Time elapsed:                             234.08 mins
# KL between old and new distribution:      0.009111967
# Entropy:                                  0.2562468
# Surrogate loss:                           50.080135
#
# ********** Iteration 527 ************
# Rollout
# Made rollout
# Total number of episodes:                 149031
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               22.996007580297405
# Time elapsed:                             234.48 mins
# KL between old and new distribution:      0.009433508
# Entropy:                                  0.25614592
# Surrogate loss:                           46.72564
#
# ********** Iteration 528 ************
# Rollout
# Made rollout
# Total number of episodes:                 149608
# Average sum of rewards per episode:       -85.65857885615252
# Std of rewards per episode:               24.413102003913533
# Time elapsed:                             234.89 mins
# KL between old and new distribution:      0.009442706
# Entropy:                                  0.26138127
# Surrogate loss:                           46.25267
#
# ********** Iteration 529 ************
# Rollout
# Made rollout
# Total number of episodes:                 150167
# Average sum of rewards per episode:       -88.4490161001789
# Std of rewards per episode:               32.17984727416045
# Time elapsed:                             235.30 mins
# KL between old and new distribution:      0.009178624
# Entropy:                                  0.2534525
# Surrogate loss:                           49.99469
#
# ********** Iteration 530 ************
# Rollout
# Made rollout
# Total number of episodes:                 150730
# Average sum of rewards per episode:       -87.81172291296625
# Std of rewards per episode:               24.324699733041285
# Time elapsed:                             235.71 mins
# KL between old and new distribution:      0.0084620975
# Entropy:                                  0.2569952
# Surrogate loss:                           47.233116
#
# ********** Iteration 531 ************
# Rollout
# Made rollout
# Total number of episodes:                 151285
# Average sum of rewards per episode:       -89.0954954954955
# Std of rewards per episode:               36.99286365897376
# Time elapsed:                             236.12 mins
# KL between old and new distribution:      0.009928301
# Entropy:                                  0.2507429
# Surrogate loss:                           52.13582
#
# ********** Iteration 532 ************
# Rollout
# Made rollout
# Total number of episodes:                 151858
# Average sum of rewards per episode:       -86.26178010471205
# Std of rewards per episode:               23.939595778665247
# Time elapsed:                             236.53 mins
# KL between old and new distribution:      0.009265125
# Entropy:                                  0.25549734
# Surrogate loss:                           46.406986
#
# ********** Iteration 533 ************
# Rollout
# Made rollout
# Total number of episodes:                 152423
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               25.691954803483643
# Time elapsed:                             236.94 mins
# KL between old and new distribution:      0.0099619925
# Entropy:                                  0.25232345
# Surrogate loss:                           47.47517
#
# ********** Iteration 534 ************
# Rollout

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.cc/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the MCTS seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about TRPO in the [original paper](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cumulative rewards similar to `get_cumulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gymnasium.farama.org/environments/mujoco/#mujoco)
# * [Box2d robot](https://gymnasium.farama.org/environments/box2d/bipedal_walker/)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use a fully factorized gaussian (basically a vector of gaussians).
#
# __Bonus task__: compare the performance of the continuous action space method to action space discretization.
